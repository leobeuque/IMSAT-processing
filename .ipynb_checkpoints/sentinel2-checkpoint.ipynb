# %% [markdown]
# # Sentinel image preprocessing
#
# *Aim*:
# >- creating a `Geotif` file from selected channels
#
#
# **Steps**
#
# >- polygon
# >- unzip Sentinel-2 data
# >- preparation of the `polygon`
# >- channel selection
# >- resampling
# >- trimming (clipping) images
# >- save data

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import rasterio
from pathlib import Path
import zipfile
from shapely import geometry
import os, sys, re

# %%
# %cd /home/u1/22_dydaktyka/05imProc/rok2021
# Out:
# /home/u1/22_dydaktyka/05imProc/rok2021

# %%
# %ls ../img_test/
# Out:
# S2B_MSIL2A_20210326T100029_N0214_R122_T33UXV_20210326T124311.zip

# %% [markdown]
# # Polygon
#
# >Copy the coordinates of the novel polygon from previous classes (sentinel1.ipynb)

# %%
cordsUtm = [(649349.16, 5985886.59),
 (679349.16, 5985886.59),
 (679349.16, 5955886.59),
 (649349.16, 5955886.59)]
cordsUtm
# Out:
# [(649349.16, 5985886.59),
#  (679349.16, 5985886.59),
#  (679349.16, 5955886.59),
#  (649349.16, 5955886.59)]

# %%
poly = geometry.asPolygon(cordsUtm)
poly

# %% [markdown]
# # Unzip
#
# >- `zipfile` module — work with ZIP archives
# >- [zipfile documentation](https://docs.python.org/3/library/zipfile.html)

# %%
zipName = '../img_test/S2B_MSIL2A_20210326T100029_N0214_R122_T33UXV_20210326T124311.zip'

# %%
with zipfile.ZipFile(zipName,"r") as fz:
    print('Files in zip: ',len(fz.filelist))
    fz.extractall('imgs/')
# Out:
# Files in zip:  146

# %%
# %ls imgs/
# Out:
# cameraman.tif
# L2A_20200412_T34UDA_cliped.tif
# lena_color_512.tif
# lena_gray_512.tif
# peppers_color.jpg
# S2B_MSIL2A_20210326T100029_N0214_R122_T33UXV_20210326T124311.SAFE/
# S2L2A_20210326T33UXV/
# sent.jpg
# swornegacie/

# %% [markdown]
# # Short name

# %%
old = Path('imgs/S2B_MSIL2A_20210326T100029_N0214_R122_T33UXV_20210326T124311.SAFE/')
old
# Out:
# PosixPath('imgs/S2B_MSIL2A_20210326T100029_N0214_R122_T33UXV_20210326T124311.SAFE')

# %%
new = Path('imgs/S2L2A_20210326T33UXV')

if not new.is_dir():
    old.rename(new)

# %%
# %ls imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A021169_20210326T100025/IMG_DATA/
# Out:
# R10m/  R20m/  R60m/

# %% [markdown]
# # Image selecting

# %%
folder = Path('imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A021169_20210326T100025/IMG_DATA/')
folder
# Out:
# PosixPath('imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A021169_20210326T100025/IMG_DATA')

# %%
for f in folder.glob('*/*B*'):
    print(f.name)
# Out:
# T33UXV_20210326T100029_B02_10m.jp2
# T33UXV_20210326T100029_B04_10m.jp2
# T33UXV_20210326T100029_B03_10m.jp2
# T33UXV_20210326T100029_B08_10m.jp2
# T33UXV_20210326T100029_B02_20m.jp2
# T33UXV_20210326T100029_B06_20m.jp2
# T33UXV_20210326T100029_B11_20m.jp2
# T33UXV_20210326T100029_B03_20m.jp2
# T33UXV_20210326T100029_B8A_20m.jp2
# T33UXV_20210326T100029_B05_20m.jp2
# T33UXV_20210326T100029_B04_20m.jp2
# T33UXV_20210326T100029_B07_20m.jp2
# T33UXV_20210326T100029_B12_20m.jp2
# T33UXV_20210326T100029_B02_60m.jp2
# T33UXV_20210326T100029_B12_60m.jp2
# T33UXV_20210326T100029_B05_60m.jp2
# T33UXV_20210326T100029_B04_60m.jp2
# T33UXV_20210326T100029_B07_60m.jp2
# T33UXV_20210326T100029_B11_60m.jp2
# T33UXV_20210326T100029_B03_60m.jp2
# T33UXV_20210326T100029_B01_60m.jp2
# T33UXV_20210326T100029_B09_60m.jp2
# T33UXV_20210326T100029_B06_60m.jp2
# T33UXV_20210326T100029_B8A_60m.jp2

# %%
bands = []
for f in folder.glob('*/*B*'):
    #print(re.search(r'(B.{2}).*(\d\d)',f.name).groups())
    tmp = list(re.search(r'(B.{2})_{1}(\d\d)',f.name).groups())
    
    tmp.append(f.as_posix())
    #print(tmp)
    bands.append(tmp)
    
    
df = pd.DataFrame(bands,columns=['name','resolu','add'])
df
# Out:
#    name resolu                                                add
# 0   B02     10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 1   B04     10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 2   B03     10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 3   B08     10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 4   B02     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 5   B06     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 6   B11     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 7   B03     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 8   B8A     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 9   B05     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 10  B04     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 11  B07     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 12  B12     20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 13  B02     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 14  B12     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 15  B05     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 16  B04     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 17  B07     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 18  B11     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 19  B03     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 20  B01     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 21  B09     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 22  B06     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# 23  B8A     60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...

# %%
df = df.groupby('name').min()
df
# Out:
#      resolu                                                add
# name
# B01      60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B02      10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B03      10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B04      10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B05      20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B06      20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B07      20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B08      10  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B09      60  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B11      20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B12      20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...
# B8A      20  imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A...

# %% [markdown]
# # Show some img
#
# ## Single channel with polygon

# %%
x,y = poly.boundary.coords.xy
print(x,y,sep='\n\n')
# Out:
# array('d', [649349.16, 679349.16, 679349.16, 649349.16, 649349.16])
#
# array('d', [5985886.59, 5985886.59, 5955886.59, 5955886.59, 5985886.59])

# %%
fg = plt.figure(figsize=(7,7))
with rasterio.open(df.iloc[1,-1]) as src:
    ar = src.read(1)
    
    # convert UTM coordinates to rows and cols of numpy array 
    afine = src.transform
    cols,rows = rasterio.transform.rowcol(afine,x,y)

plt.imshow(ar,vmax=2500,cmap='gray');
plt.plot(rows,cols,'-',lw=4,c='r');

# %% [markdown]
# ## Histograms

# %%
f,axs = plt.subplots(3,4,figsize=(10,6))


for i,ax in enumerate(axs.ravel()):
    tmpAdd = df.iloc[i,-1]
    with rasterio.open(tmpAdd) as fm:
        im = fm.read(1)
    ax.hist(im.ravel(),bins=256)
        
plt.tight_layout()

# %% [markdown]
# ## Selected channels

# %%
f,axs = plt.subplots(3,4,figsize=(10,8))


for i,ax in enumerate(axs.ravel()):
    tmpAdd = df.iloc[i,-1]
    with rasterio.open(tmpAdd) as fm:
        im = fm.read(1)
    ax.imshow(im,cmap='gray',vmax=2500)
        
plt.tight_layout()

# %% [markdown]
# # Resampling & clipping

# %% [markdown]
# ## Out Folder
#
# >If there is no folder to write an output image - create it.

# %%
outFold = Path('imgs/swornegacie/')
if not outFold.is_dir():
    outFold.mkdir()

# %% [markdown]
# ## Import modules

# %%
from rasterio.enums import Resampling
from rasterio import mask
from rasterio.io import MemoryFile

# %% [markdown]
# ## Set metadata
# The channel metadata with the highest resolution will be used when resampling other channels. Updates meta:
# >- `GTiff` - out driver
# >- `nodata` - set to max value for 12 bits image ($2^{12}$)
# >- `count` - noumber of bands
#
# In addition to metadata, define arguments `outShape` and `metaTmp`, which will be used when resampling and save data to a temporary file.

# %%
df.iloc[0,-1]
# Out:
# 'imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A021169_20210326T100025/IMG_DATA/R60m/T33UXV_20210326T100029_B01_60m.jp2'

# %%
with rasterio.open(df.iloc[0,-1]) as fm:
    print(fm.meta)
# Out:
# {'driver': 'JP2OpenJPEG', 'dtype': 'uint16', 'nodata': None, 'width': 1830, 'height': 1830, 'count': 1, 'crs': CRS.from_epsg(32633), 'transform': Affine(60.0, 0.0, 600000.0,
#        0.0, -60.0, 6000000.0)}

# %%
df.iloc[1,-1]
# Out:
# 'imgs/S2L2A_20210326T33UXV/GRANULE/L2A_T33UXV_A021169_20210326T100025/IMG_DATA/R10m/T33UXV_20210326T100029_B02_10m.jp2'

# %%
metaOut = None
metaTmp = None

with rasterio.open(df.iloc[1,-1]) as src: 
    metaOut = src.meta
    metaOut['driver'] = 'GTiff'
    metaOut['nodata'] = 2**12
    metaOut['count'] = df.shape[0]
                
    metaTmp = src.meta
    metaTmp['count'] = 1
    
    outShape = (metaOut['height'],metaOut['width'])
    
metaOut
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': 4096,
#  'width': 10980,
#  'height': 10980,
#  'count': 12,
#  'crs': CRS.from_epsg(32633),
#  'transform': Affine(10.0, 0.0, 600000.0,
#         0.0, -10.0, 6000000.0)}

# %% [markdown]
# ## Resampling/clipping

# %%
outData = []


for i in range(df.shape[0]):
    add = df.iloc[i,1]
    
    with rasterio.open(add) as src:                 
        if int(df.iloc[i,0]) > 10:
            data = src.read(1,out_shape = outShape, resampling = Resampling.nearest)
        else:
            data = src.read(1)
    #print(data.shape)

        
    with MemoryFile() as memfile:
        with memfile.open(**metaTmp) as dataset:
            dataset.write(data,1)
            out_image, out_transform = mask.mask(dataset, [poly], crop=True)
            out_image = np.transpose(out_image,(1,2,0))
            out_image = out_image[:,:,0].copy()
            outData.append(out_image)
            print(out_image.shape, df.iloc[i,0],df.index[i])
        
metaOut.update({"height": out_image.shape[0],
                 "width": out_image.shape[1],
                 "transform": out_transform})
# Out:
# (3001, 3001) 60 B01
# (3001, 3001) 10 B02
# (3001, 3001) 10 B03
# (3001, 3001) 10 B04
# (3001, 3001) 20 B05
# (3001, 3001) 20 B06
# (3001, 3001) 20 B07
# (3001, 3001) 10 B08
# (3001, 3001) 60 B09
# (3001, 3001) 20 B11
# (3001, 3001) 20 B12
# (3001, 3001) 20 B8A

# %%
len(outData)
# Out:
# 12

# %%
df.index
# Out:
# Index(['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B09', 'B11',
#        'B12', 'B8A'],
#       dtype='object', name='name')

# %% [markdown]
# # Save geoTiff

# %%
dst_addres = 'imgs/swornegacie/readyImage.tif'

with rasterio.open(dst_addres,'w',**metaOut) as dst:
    for i,ar in enumerate(outData,1):
        dst.write(ar,i)
        dst.set_band_description(i,df.index[i-1])
